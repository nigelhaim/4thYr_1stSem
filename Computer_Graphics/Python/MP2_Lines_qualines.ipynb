# %% [markdown]
# # MP

# %% [markdown]
# ## Install and Imports

# %%
from PIL import Image, ImageDraw, ImageFont

# %%
bg = 256
line_width = 8 
font = ImageFont.truetype("arial.ttf", 20)
image_height = 800
image_width = 800

# %%
image = Image.new('RGB', (image_width, image_height), color = (bg, bg, bg))
image
# Out:
# <PIL.Image.Image image mode=RGB size=800x800>

# %%
draw = ImageDraw.Draw(image)
