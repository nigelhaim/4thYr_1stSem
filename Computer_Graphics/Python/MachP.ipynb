# %%
from PIL import Image, ImageDraw, ImageFont

# %%
def quad_curve(t, p0, p1, p2):
    x = (1-t)**2 * p0[0] + 2 * (1-t) * t * p1[0] + t**2 * p2[0]
    y = (1-t)**2 * p0[1] + 2 * (1-t) * t * p1[1] + t**2 * p2[1]
    return x, y

# %%
image = Image.new('RGB', (700, 700), 'white')
draw = ImageDraw.Draw(image)
draw.line((250, 280, 350, 280), fill='black')
p0 = (350, 280)
c1 = (390, 280)
p2 = (390, 320)
t = 0.5

def quad_curve(t, p0, p1, p2):
    x = (1-t)**2 * p0[0] + 2 * (1-t) * t * p1[0] + t**2 * p2[0]
    y = (1-t)**2 * p0[1] + 2 * (1-t) * t * p1[1] + t**2 * p2[1]
    return x, y
points = [quad_curve(t, p0, c1, p2) for t in [i/100 for i in range(101)]]
draw.line(points, fill='black')

p0 = (390, 320)
c1 = (390, 360)
p2 = (350, 360)
t = 0.5

points = [quad_curve(t, p0, c1, p2) for t in [i/100 for i in range(101)]]
draw.line(points, fill='black')

draw.line((350, 360, 250, 360), fill='black')
draw.line((250, 360, 250, 460), fill='black')

p0 = (250, 460)
c1 = (250, 500)
p2 = (210, 500)
points = [quad_curve(t, p0, c1, p2) for t in [i/100 for i in range(101)]]
draw.line(points, fill='black')


p0 = (210, 500)
c1 = (170, 500)
p2 = (170, 460)
points = [quad_curve(t, p0, c1, p2) for t in [i/100 for i in range(101)]]
draw.line(points, fill='black')

draw.line((170, 460, 170, 360), fill='black')
draw.line((170, 360, 70, 360), fill='black')

p0 = (70, 360)
c1 = (30, 360)
p2 = (30, 320)
points = [quad_curve(t, p0, c1, p2) for t in [i/100 for i in range(101)]]
draw.line(points, fill='black')

p0 = (30, 320)
c1 = (30, 280)
p2 = (70, 280)
points = [quad_curve(t, p0, c1, p2) for t in [i/100 for i in range(101)]]
draw.line(points, fill='black')

draw.line((70, 280, 170, 280), fill='black')

draw.line((170, 280, 170, 180), fill='black')

p0 = (170, 180)
c1 = (170, 140)
p2 = (210, 140)
points = [quad_curve(t, p0, c1, p2) for t in [i/100 for i in range(101)]]
draw.line(points, fill='black')

p0 = (210, 140)
c1 = (250, 140)
p2 = (250, 180)
points = [quad_curve(t, p0, c1, p2) for t in [i/100 for i in range(101)]]
draw.line(points, fill='black')

draw.line((250, 180, 250, 280), fill='black')

# %%
image
# Out:
# <PIL.Image.Image image mode=RGB size=700x700>
