# %% [markdown]
# # Sebastian_LE-Lab

# %% [markdown]
# Filename: FamilyName_LE-Lab (pdf)
#
# 1. (14 points) Draw the following images:
#
# - (a) spheres whose radius is 25 and 300 resolution
#
# - (b) the pyramid with a rectangular base (50 by 45) with height 30 and resolution 300
#
#
#
# 2. Perform the following in the stated image.
#
# - (a)  (14 points) Rotate the pyramid at the following angles  75 degrees  with respect to X , Y and Z axis
#
# - (b)  (14 points) Translate the rotated object in (2.a)  using (Tx, Ty, Tz)  = (-10, 30, 25)
#
# - (c) (14 points) Scale the sphere using the given parameters c.1) (Sx, Sy, Sz) = (0.25, 4, 1) , c.2) (Sx, Sy, Sz) = (2, 5, -1)
#
# - (4) (14 points) Rotate  the scaled sphere at 75 degress with respect to X, Y and Z axis. Compare the results.

# %% [markdown]
# ## Imports

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from mpl_toolkits.mplot3d.art3d import Poly3DCollection
import math
from matplotlib import cm

# %% [markdown]
# ## 1. (14 points) Draw the following images:

# %% [markdown]
# ### (a) spheres whose radius is 25 and 300 resolution

# %%
#DRAWING A SPHERE
# Define the radius of the sphere
radius = 25
num_points = 300

# Create a meshgrid for the spherical coordinates (theta, phi)
theta = np.linspace(0, 2 * np.pi, num_points)  # Azimuthal angle
phi = np.linspace(0, np.pi, num_points)        # Polar angle
theta, phi = np.meshgrid(theta, phi)


# Parametric equations for the sphere
x = radius * np.sin(phi) * np.cos(theta)
y = radius * np.sin(phi) * np.sin(theta)
z = radius * np.cos(phi)

# %%
# Create a 3D plot
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# Plot the surface of the sphere
ax.plot_surface(x, y, z, color='magenta', edgecolor='RED', linewidth=0.5)

# Set labels for clarity
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')

# Display the plot
plt.show()

# %% [markdown]
# ### (b) the pyramid with a rectangular base (50 by 45) with height 30 ~~and resolution 300~~

# %%
#DRAWING PRISM
# Parameters for the rectangular prism
length = 45  # Length of the prism
width = 50  # Width of the prism
height =30  # Height of the prism

# Define the vertices of the rectangular prism
vertices = np.array([
    [-length/2, -width/2, 0],  # Base corner 1
    [ length/2, -width/2, 0],  # Base corner 2
    [ length/2,  width/2, 0],  # Base corner 3
    [-length/2,  width/2, 0],  # Base corner 4
    [ 0, 0, height]    
])

faces = [
    [vertices[0], vertices[1], vertices[4]],  # Front face
    [vertices[1], vertices[2], vertices[4]],  # Right face
    [vertices[2], vertices[3], vertices[4]],  # Back face
    [vertices[3], vertices[0], vertices[4]],  # Left face
    [vertices[0], vertices[1], vertices[2], vertices[3]]  # Base face
]

# %%
# Create the 3D plot
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# Plot the pyramid
ax.add_collection3d(Poly3DCollection(faces, facecolors='green', linewidths=1, edgecolors='RED', alpha=.5))

# Set labels for clarity
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')

# Set the limits for the axes
ax.set_xlim([-length, width])
ax.set_ylim([-length, width])
ax.set_zlim([0, height])

# Display the plot
plt.show()

# %% [markdown]
# ## 2. Perform the following in the stated image.

# %% [markdown]
# ### (a)  (14 points) Rotate the pyramid at the following angles  75 degrees  with respect to X , Y and Z axis

# %%
rotation_angle = 75 * np.pi / 180  # 75 degrees in radians

# %%
angle_in_degrees = np.degrees(rotation_angle)
print(round(angle_in_degrees, 2))
# Out:
# 75.0

# %% [markdown]
# #### y axis rotation

# %%
# Apply rotation around the x-axis
y_rotation_matrix = np.array([
    [1, 0, 0],
    [0, np.cos(rotation_angle), -np.sin(rotation_angle)],
    [0, np.sin(rotation_angle), np.cos(rotation_angle)]
])

# %%
#DRAWING PRISM
# Parameters for the rectangular prism
length = 45  # Length of the prism
width = 50  # Width of the prism
height =30  # Height of the prism

# Define the vertices of the rectangular prism
vertices = np.array([
    [-length/2, -width/2, 0],  # Base corner 1
    [ length/2, -width/2, 0],  # Base corner 2
    [ length/2,  width/2, 0],  # Base corner 3
    [-length/2,  width/2, 0],  # Base corner 4
    [ 0, 0, height]    
])


faces = [
    [vertices[0], vertices[1], vertices[4]],  # Front face
    [vertices[1], vertices[2], vertices[4]],  # Right face
    [vertices[2], vertices[3], vertices[4]],  # Back face
    [vertices[3], vertices[0], vertices[4]],  # Left face
    [vertices[0], vertices[1], vertices[2], vertices[3]]  # Base face
]

rotated_vertices = np.dot(vertices, y_rotation_matrix)

rotated_faces = [
    [rotated_vertices[0], rotated_vertices[1], rotated_vertices[4]],  # Front face
    [rotated_vertices[1], rotated_vertices[2], rotated_vertices[4]],  # Right face
    [rotated_vertices[2], rotated_vertices[3], rotated_vertices[4]],  # Back face
    [rotated_vertices[3], rotated_vertices[0], rotated_vertices[4]],  # Left face
    [rotated_vertices[0], rotated_vertices[1], rotated_vertices[2], rotated_vertices[3]]  # Base face
]

# %%
# Plot original and rotated cones
fig = plt.figure(figsize=(10, 5))

# Original Cone
ax1 = fig.add_subplot(121, projection='3d')
# Plot the pyramid
ax1.add_collection3d(Poly3DCollection(faces, facecolors='green', linewidths=1, edgecolors='RED', alpha=.5))
# Set labels for clarity
ax1.set_xlabel('X')
ax1.set_ylabel('Y')
ax1.set_zlabel('Z')
# Set the limits for the axes
ax1.set_xlim([-length, width])
ax1.set_ylim([-length, width])
ax1.set_zlim([0, height])
# Rotated Cone
ax2 = fig.add_subplot(122, projection='3d')
# Plot the pyramid
ax2.add_collection3d(Poly3DCollection(rotated_faces, facecolors='green', linewidths=1, edgecolors='RED', alpha=.5))
# Set labels for clarity
ax2.set_xlabel('X')
ax2.set_ylabel('Y')
ax2.set_zlabel('Z')
# Set the limits for the axes
ax2.set_xlim([-length, length])
ax2.set_ylim([-width, width])
ax1.set_zlim([0, height])

plt.show()

# %% [markdown]
# #### x axis rotation

# %%
# Apply rotation around the Y-axis
x_rotation_matrix = np.array([
    [np.cos(rotation_angle), 0, np.sin(rotation_angle)],
    [0, 1, 0],
    [-np.sin(rotation_angle), 0, np.cos(rotation_angle)]
])

# %%
#DRAWING PRISM
# Parameters for the rectangular prism
length = 45  # Length of the prism
width = 50  # Width of the prism
height =30  # Height of the prism

# Define the vertices of the rectangular prism
vertices = np.array([
    [-length/2, -width/2, 0],  # Base corner 1
    [ length/2, -width/2, 0],  # Base corner 2
    [ length/2,  width/2, 0],  # Base corner 3
    [-length/2,  width/2, 0],  # Base corner 4
    [ 0, 0, height]    
])


faces = [
    [vertices[0], vertices[1], vertices[4]],  # Front face
    [vertices[1], vertices[2], vertices[4]],  # Right face
    [vertices[2], vertices[3], vertices[4]],  # Back face
    [vertices[3], vertices[0], vertices[4]],  # Left face
    [vertices[0], vertices[1], vertices[2], vertices[3]]  # Base face
]

rotated_vertices = np.dot(vertices, x_rotation_matrix)

rotated_faces = [
    [rotated_vertices[0], rotated_vertices[1], rotated_vertices[4]],  # Front face
    [rotated_vertices[1], rotated_vertices[2], rotated_vertices[4]],  # Right face
    [rotated_vertices[2], rotated_vertices[3], rotated_vertices[4]],  # Back face
    [rotated_vertices[3], rotated_vertices[0], rotated_vertices[4]],  # Left face
    [rotated_vertices[0], rotated_vertices[1], rotated_vertices[2], rotated_vertices[3]]  # Base face
]

# %%
# Plot original and rotated cones
fig = plt.figure(figsize=(10, 5))


# Original Cone
ax1 = fig.add_subplot(121, projection='3d')
# Plot the pyramid
ax1.add_collection3d(Poly3DCollection(faces, facecolors='green', linewidths=1, edgecolors='RED', alpha=.5))
# Set labels for clarity
ax1.set_xlabel('X')
ax1.set_ylabel('Y')
ax1.set_zlabel('Z')
# Set the limits for the axes
ax1.set_xlim([-length, width])
ax1.set_ylim([-length, width])
ax1.set_zlim([0, height])
# Rotated Cone
ax2 = fig.add_subplot(122, projection='3d')
# Plot the pyramid
ax2.add_collection3d(Poly3DCollection(rotated_faces, facecolors='green', linewidths=1, edgecolors='RED', alpha=.5))
# Set labels for clarity
ax2.set_xlabel('X')
ax2.set_ylabel('Y')
ax2.set_zlabel('Z')
# Set the limits for the axes
ax2.set_xlim([-length, length])
ax2.set_ylim([-width, width])
ax1.set_zlim([0, height])

plt.show()

# %% [markdown]
# #### z axis

# %%
z_rotation_matrix = np.array([
    [np.cos(rotation_angle), -np.sin(rotation_angle), 0],
    [np.sin(rotation_angle), np.cos(rotation_angle), 0],
    [0, 0, 1]
])

# %%
#DRAWING PRISM
# Parameters for the rectangular prism
length = 45  # Length of the prism
width = 50  # Width of the prism
height =30  # Height of the prism

# Define the vertices of the rectangular prism
vertices = np.array([
    [-length/2, -width/2, 0],  # Base corner 1
    [ length/2, -width/2, 0],  # Base corner 2
    [ length/2,  width/2, 0],  # Base corner 3
    [-length/2,  width/2, 0],  # Base corner 4
    [ 0, 0, height]    
])


faces = [
    [vertices[0], vertices[1], vertices[4]],  # Front face
    [vertices[1], vertices[2], vertices[4]],  # Right face
    [vertices[2], vertices[3], vertices[4]],  # Back face
    [vertices[3], vertices[0], vertices[4]],  # Left face
    [vertices[0], vertices[1], vertices[2], vertices[3]]  # Base face
]

rotated_vertices = np.dot(vertices, z_rotation_matrix)

rotated_faces = [
    [rotated_vertices[0], rotated_vertices[1], rotated_vertices[4]],  # Front face
    [rotated_vertices[1], rotated_vertices[2], rotated_vertices[4]],  # Right face
    [rotated_vertices[2], rotated_vertices[3], rotated_vertices[4]],  # Back face
    [rotated_vertices[3], rotated_vertices[0], rotated_vertices[4]],  # Left face
    [rotated_vertices[0], rotated_vertices[1], rotated_vertices[2], rotated_vertices[3]]  # Base face
]

# %%
# Plot original and rotated cones
fig = plt.figure(figsize=(10, 5))

# Original Cone
ax1 = fig.add_subplot(121, projection='3d')
# Plot the pyramid
ax1.add_collection3d(Poly3DCollection(faces, facecolors='green', linewidths=1, edgecolors='RED', alpha=.5))
# Set labels for clarity
ax1.set_xlabel('X')
ax1.set_ylabel('Y')
ax1.set_zlabel('Z')
# Set the limits for the axes
ax1.set_xlim([-length, width])
ax1.set_ylim([-length, width])
ax1.set_zlim([0, height])
# Rotated Cone
ax2 = fig.add_subplot(122, projection='3d')
# Plot the pyramid
ax2.add_collection3d(Poly3DCollection(rotated_faces, facecolors='green', linewidths=1, edgecolors='RED', alpha=.5))
# Set labels for clarity
ax2.set_xlabel('X')
ax2.set_ylabel('Y')
ax2.set_zlabel('Z')
# Set the limits for the axes
ax2.set_xlim([-length, length])
ax2.set_ylim([-width, width])
ax1.set_zlim([0, height])

plt.show()

# %% [markdown]
# #### All rotations

# %%
# Apply rotation around the x-axis
x_rotation_matrix = np.array([
    [1, 0, 0],
    [0, np.cos(rotation_angle), -np.sin(rotation_angle)],
    [0, np.sin(rotation_angle), np.cos(rotation_angle)]
])


# Apply rotation around the Y-axis
y_rotation_matrix = np.array([
    [np.cos(rotation_angle), 0, np.sin(rotation_angle)],
    [0, 1, 0],
    [-np.sin(rotation_angle), 0, np.cos(rotation_angle)]
])

# Apply rotation around the z-axis
z_rotation_matrix = np.array([
    [np.cos(rotation_angle), -np.sin(rotation_angle), 0],
    [np.sin(rotation_angle), np.cos(rotation_angle), 0],
    [0, 0, 1]
])

all_rotations = np.dot(z_rotation_matrix, np.dot(y_rotation_matrix, x_rotation_matrix))

# %%
#DRAWING PRISM
# Parameters for the rectangular prism
length = 45  # Length of the prism
width = 50  # Width of the prism
height =30  # Height of the prism

# Define the vertices of the rectangular prism
vertices = np.array([
    [-length/2, -width/2, 0],  # Base corner 1
    [ length/2, -width/2, 0],  # Base corner 2
    [ length/2,  width/2, 0],  # Base corner 3
    [-length/2,  width/2, 0],  # Base corner 4
    [ 0, 0, height]    
])


faces = [
    [vertices[0], vertices[1], vertices[4]],  # Front face
    [vertices[1], vertices[2], vertices[4]],  # Right face
    [vertices[2], vertices[3], vertices[4]],  # Back face
    [vertices[3], vertices[0], vertices[4]],  # Left face
    [vertices[0], vertices[1], vertices[2], vertices[3]]  # Base face
]


all_rotations = np.dot(z_rotation_matrix, np.dot(y_rotation_matrix, x_rotation_matrix))
rotated_vertices = np.dot(vertices, all_rotations)

rotated_faces = [
    [rotated_vertices[0], rotated_vertices[1], rotated_vertices[4]],  # Front face
    [rotated_vertices[1], rotated_vertices[2], rotated_vertices[4]],  # Right face
    [rotated_vertices[2], rotated_vertices[3], rotated_vertices[4]],  # Back face
    [rotated_vertices[3], rotated_vertices[0], rotated_vertices[4]],  # Left face
    [rotated_vertices[0], rotated_vertices[1], rotated_vertices[2], rotated_vertices[3]]  # Base face
]

# %%
# Plot original and rotated cones
fig = plt.figure(figsize=(10, 5))

# Original Cone
ax1 = fig.add_subplot(121, projection='3d')
# Plot the pyramid
ax1.add_collection3d(Poly3DCollection(faces, facecolors='green', linewidths=1, edgecolors='RED', alpha=.5))
# Set labels for clarity
ax1.set_xlabel('X')
ax1.set_ylabel('Y')
ax1.set_zlabel('Z')
# Set the limits for the axes
ax1.set_xlim([-length, width])
ax1.set_ylim([-length, width])
ax1.set_zlim([0, height])
# Rotated Cone
ax2 = fig.add_subplot(122, projection='3d')
# Plot the pyramid
ax2.add_collection3d(Poly3DCollection(rotated_faces, facecolors='green', linewidths=1, edgecolors='RED', alpha=.5))
# Set labels for clarity
ax2.set_xlabel('X')
ax2.set_ylabel('Y')
ax2.set_zlabel('Z')
# Set the limits for the axes
ax2.set_xlim([-length, length])
ax2.set_ylim([-width, width])
ax1.set_zlim([0, height])

plt.show()

# %% [markdown]
# ### (14 points) Translate the rotated object in (2.a)  using (Tx, Ty, Tz)  = (-10, 30, 25)

# %%
translation = [-10,30,25]

# %%
#DRAWING PRISM
# Parameters for the rectangular prism
length = 45  # Length of the prism
width = 50  # Width of the prism
height =30  # Height of the prism

# Define the vertices of the rectangular prism
vertices = np.array([
    [-length/2, -width/2, 0],  # Base corner 1
    [ length/2, -width/2, 0],  # Base corner 2
    [ length/2,  width/2, 0],  # Base corner 3
    [-length/2,  width/2, 0],  # Base corner 4
    [ 0, 0, height]    
])



faces = [
    [vertices[0], vertices[1], vertices[4]],  # Front face
    [vertices[1], vertices[2], vertices[4]],  # Right face
    [vertices[2], vertices[3], vertices[4]],  # Back face
    [vertices[3], vertices[0], vertices[4]],  # Left face
    [vertices[0], vertices[1], vertices[2], vertices[3]]  # Base face
]


all_rotations = np.dot(z_rotation_matrix, np.dot(y_rotation_matrix, x_rotation_matrix))
rotated_vertices = np.dot(vertices, all_rotations)

# Translate the vertices
translated_vertices = rotated_vertices + translation


translated_faces = [
    [translated_vertices[0], translated_vertices[1], translated_vertices[4]],  # Front face
    [translated_vertices[1], translated_vertices[2], translated_vertices[4]],  # Right face
    [translated_vertices[2], translated_vertices[3], translated_vertices[4]],  # Back face
    [translated_vertices[3], translated_vertices[0], translated_vertices[4]],  # Left face
    [translated_vertices[0], translated_vertices[1], translated_vertices[2], translated_vertices[3]]  # Base face
]

# %%
# Plot original and rotated cones
fig = plt.figure(figsize=(10, 5))

# Original Cone
ax1 = fig.add_subplot(121, projection='3d')
# Plot the pyramid
ax1.add_collection3d(Poly3DCollection(faces, facecolors='green', linewidths=1, edgecolors='RED', alpha=.5))
# Set labels for clarity
ax1.set_xlabel('X')
ax1.set_ylabel('Y')
ax1.set_zlabel('Z')
# Set the limits for the axes
ax1.set_xlim([-length, width])
ax1.set_ylim([-length, width])
ax1.set_zlim([0, height])
# Rotated Cone
ax2 = fig.add_subplot(122, projection='3d')
# Plot the pyramid
ax2.add_collection3d(Poly3DCollection(translated_faces, facecolors='green', linewidths=1, edgecolors='RED', alpha=.5))
# Set labels for clarity
ax2.set_xlabel('X')
ax2.set_ylabel('Y')
ax2.set_zlabel('Z')
# Set the limits for the axes
ax2.set_xlim([-length, length])
ax2.set_ylim([-width, width])
ax1.set_zlim([0, height])

plt.show()

# %% [markdown]
# ### (c) (14 points) Scale the sphere using the given parameters
# - c.1) (Sx, Sy, Sz) = (0.25, 4, 1)
# - c.2) (Sx, Sy, Sz) = (2, 5, -1)

# %% [markdown]
# #### c.1) (Sx, Sy, Sz) = (0.25, 4, 1)

# %%
scaling_factors = [0.25,4,1]

# %%
#DRAWING A SPHERE
# Define the radius of the sphere
radius = 25
num_points = 300

# Create a meshgrid for the spherical coordinates (theta, phi)
theta = np.linspace(0, 2 * np.pi, num_points)  # Azimuthal angle
phi = np.linspace(0, np.pi, num_points)        # Polar angle
theta, phi = np.meshgrid(theta, phi)


# Parametric equations for the sphere
x = radius * np.sin(phi) * np.cos(theta)
y = radius * np.sin(phi) * np.sin(theta)
z = radius * np.cos(phi)

# Scale the sphere
scaled_x = x * scaling_factors[0]
scaled_y = y * scaling_factors[1]
scaled_z = z * scaling_factors[2]

# %%
fig = plt.figure(figsize=(10, 5))

# Original Cylinder
ax1 = fig.add_subplot(121, projection='3d')
# Plot the surface of the sphere
ax1.plot_surface(x, y, z, color='magenta', edgecolor='RED', linewidth=0.5)

# Set labels for clarity
ax1.set_xlabel('X')
ax1.set_ylabel('Y')
ax1.set_zlabel('Z')

# Scaled Cylinder
ax2 = fig.add_subplot(122, projection='3d')
# Plot the surface of the sphere
ax2.plot_surface(scaled_x, scaled_y, scaled_z, color='magenta', edgecolor='RED', linewidth=0.5)

# Set labels for clarity
ax2.set_xlabel('X')
ax2.set_ylabel('Y')
ax2.set_zlabel('Z')

plt.show()

# %% [markdown]
# #### c.2) (Sx, Sy, Sz) = (2, 5, -1)

# %%
scaling_factors = [2,5,-1]

# %%
#DRAWING A SPHERE
# Define the radius of the sphere
radius = 25
num_points = 300

# Create a meshgrid for the spherical coordinates (theta, phi)
theta = np.linspace(0, 2 * np.pi, num_points)  # Azimuthal angle
phi = np.linspace(0, np.pi, num_points)        # Polar angle
theta, phi = np.meshgrid(theta, phi)


# Parametric equations for the sphere
x = radius * np.sin(phi) * np.cos(theta)
y = radius * np.sin(phi) * np.sin(theta)
z = radius * np.cos(phi)

# Scale the sphere
scaled_x = x * scaling_factors[0]
scaled_y = y * scaling_factors[1]
scaled_z = z * scaling_factors[2]

# %%
fig = plt.figure(figsize=(10, 5))

# Original Cylinder
ax1 = fig.add_subplot(121, projection='3d')
# Plot the surface of the sphere
ax1.plot_surface(x, y, z, color='magenta', edgecolor='RED', linewidth=0.5)

# Set labels for clarity
ax1.set_xlabel('X')
ax1.set_ylabel('Y')
ax1.set_zlabel('Z')

# Scaled Cylinder
ax2 = fig.add_subplot(122, projection='3d')
# Plot the surface of the sphere
ax2.plot_surface(scaled_x, scaled_y, scaled_z, color='magenta', edgecolor='RED', linewidth=0.5)

# Set labels for clarity
ax2.set_xlabel('X')
ax2.set_ylabel('Y')
ax2.set_zlabel('Z')

plt.show()

# %% [markdown]
# ### (4) (14 points) Rotate  the scaled sphere at 75 degress with respect to X, Y and Z axis. Compare the results.

# %%
rotation_angle = 75 * np.pi / 180  # 75 degrees in radians

# %%
angle_in_degrees = np.degrees(rotation_angle)
print(round(angle_in_degrees, 2))
# Out:
# 75.0

# %% [markdown]
# #### y axis rotation

# %%
#DRAWING A SPHERE
# Define the radius of the sphere
radius = 25
num_points = 300

# Create a meshgrid for the spherical coordinates (theta, phi)
theta = np.linspace(0, 2 * np.pi, num_points)  # Azimuthal angle
phi = np.linspace(0, np.pi, num_points)        # Polar angle
theta, phi = np.meshgrid(theta, phi)


# Parametric equations for the sphere
x = radius * np.sin(phi) * np.cos(theta)
y = radius * np.sin(phi) * np.sin(theta)
z = radius * np.cos(phi)

# Scale the sphere
scaled_x = x * scaling_factors[0]
scaled_y = y * scaling_factors[1]
scaled_z = z * scaling_factors[2]

## Rotate the sphere 
rotated_y = scaled_y * np.cos(rotation_angle) - scaled_z * np.sin(rotation_angle)

# %%
fig = plt.figure(figsize=(10, 5))

# Original Cylinder
ax1 = fig.add_subplot(121, projection='3d')
# Plot the surface of the sphere
cmap = cm.get_cmap('viridis')

# Map z-values to colors
colors = cmap(z)
ax1.plot_surface(x, y, z, facecolors=colors, edgecolor='RED', linewidth=0.5)

# Set labels for clarity
ax1.set_xlabel('X')
ax1.set_ylabel('Y')
ax1.set_zlabel('Z')

# Scaled Cylinder
ax2 = fig.add_subplot(122, projection='3d')
# Plot the surface of the sphere
ax2.plot_surface(scaled_x, rotated_y, scaled_z, facecolors=colors, edgecolor='RED', linewidth=0.5)

# Set labels for clarity
ax2.set_xlabel('X')
ax2.set_ylabel('Y')
ax2.set_zlabel('Z')

plt.show()
# Out:
# C:\Users\nigel\AppData\Local\Temp\ipykernel_24976\713667755.py:6: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap = cm.get_cmap('viridis')

# %% [markdown]
# #### x axis rotation

# %%
#DRAWING A SPHERE
# Define the radius of the sphere
radius = 25
num_points = 300

# Create a meshgrid for the spherical coordinates (theta, phi)
theta = np.linspace(0, 2 * np.pi, num_points)  # Azimuthal angle
phi = np.linspace(0, np.pi, num_points)        # Polar angle
theta, phi = np.meshgrid(theta, phi)


# Parametric equations for the sphere
x = radius * np.sin(phi) * np.cos(theta)
y = radius * np.sin(phi) * np.sin(theta)
z = radius * np.cos(phi)

# Scale the sphere
scaled_x = x * scaling_factors[0]
scaled_y = y * scaling_factors[1]
scaled_z = z * scaling_factors[2]

## Rotate the sphere 
rotated_x = scaled_x * np.cos(rotation_angle) - scaled_z * np.sin(rotation_angle)

# %%
fig = plt.figure(figsize=(10, 5))

# Original Cylinder
ax1 = fig.add_subplot(121, projection='3d')
# Plot the surface of the sphere
cmap = cm.get_cmap('viridis')

# Map z-values to colors
colors = cmap(z)
ax1.plot_surface(x, y, z, facecolors=colors, edgecolor='RED', linewidth=0.5)

# Set labels for clarity
ax1.set_xlabel('X')
ax1.set_ylabel('Y')
ax1.set_zlabel('Z')

# Scaled Cylinder
ax2 = fig.add_subplot(122, projection='3d')
# Plot the surface of the sphere
ax2.plot_surface(rotated_x, scaled_y, scaled_z, facecolors=colors, edgecolor='RED', linewidth=0.5)

# Set labels for clarity
ax2.set_xlabel('X')
ax2.set_ylabel('Y')
ax2.set_zlabel('Z')

plt.show()
# Out:
# C:\Users\nigel\AppData\Local\Temp\ipykernel_24976\3780444991.py:6: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap = cm.get_cmap('viridis')

# %% [markdown]
# #### z axis rotation

# %%
#DRAWING A SPHERE
# Define the radius of the sphere
radius = 25
num_points = 300

# Create a meshgrid for the spherical coordinates (theta, phi)
theta = np.linspace(0, 2 * np.pi, num_points)  # Azimuthal angle
phi = np.linspace(0, np.pi, num_points)        # Polar angle
theta, phi = np.meshgrid(theta, phi)


# Parametric equations for the sphere
x = radius * np.sin(phi) * np.cos(theta)
y = radius * np.sin(phi) * np.sin(theta)
z = radius * np.cos(phi)

# Scale the sphere
scaled_x = x * scaling_factors[0]
scaled_y = y * scaling_factors[1]
scaled_z = z * scaling_factors[2]

## Rotate the sphere 
rotated_z = scaled_x * np.sin(rotation_angle) + scaled_y * np.cos(rotation_angle)

# %%
fig = plt.figure(figsize=(10, 5))

# Original Cylinder
ax1 = fig.add_subplot(121, projection='3d')
# Plot the surface of the sphere
cmap = cm.get_cmap('viridis')

# Map z-values to colors
colors = cmap(z)
ax1.plot_surface(x, y, z, facecolors=colors, edgecolor='RED', linewidth=0.5)

# Set labels for clarity
ax1.set_xlabel('X')
ax1.set_ylabel('Y')
ax1.set_zlabel('Z')

# Scaled Cylinder
ax2 = fig.add_subplot(122, projection='3d')
# Plot the surface of the sphere
ax2.plot_surface(scaled_x, scaled_y, rotated_z, facecolors=colors, edgecolor='RED', linewidth=0.5)

# Set labels for clarity
ax2.set_xlabel('X')
ax2.set_ylabel('Y')
ax2.set_zlabel('Z')

plt.show()
# Out:
# C:\Users\nigel\AppData\Local\Temp\ipykernel_24976\1556440607.py:6: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap = cm.get_cmap('viridis')

# %% [markdown]
# #### all rotations

# %%
#DRAWING A SPHERE
# Define the radius of the sphere
radius = 25
num_points = 300

# Create a meshgrid for the spherical coordinates (theta, phi)
theta = np.linspace(0, 2 * np.pi, num_points)  # Azimuthal angle
phi = np.linspace(0, np.pi, num_points)        # Polar angle
theta, phi = np.meshgrid(theta, phi)


# Parametric equations for the sphere
x = radius * np.sin(phi) * np.cos(theta)
y = radius * np.sin(phi) * np.sin(theta)
z = radius * np.cos(phi)

# Scale the sphere
scaled_x = x * scaling_factors[0]
scaled_y = y * scaling_factors[1]
scaled_z = z * scaling_factors[2]

## Rotate the sphere 
rotated_x = scaled_x * np.cos(rotation_angle) - scaled_z * np.sin(rotation_angle)
rotated_y = scaled_y * np.cos(rotation_angle) - scaled_z * np.sin(rotation_angle)
rotated_z = scaled_x * np.sin(rotation_angle) + scaled_y * np.cos(rotation_angle)

# %%
fig = plt.figure(figsize=(10, 5))

# Original Cylinder
ax1 = fig.add_subplot(121, projection='3d')
# Plot the surface of the sphere
cmap = cm.get_cmap('viridis')

# Map z-values to colors
colors = cmap(z)
ax1.plot_surface(x, y, z, facecolors=colors, edgecolor='RED', linewidth=0.5)

# Set labels for clarity
ax1.set_xlabel('X')
ax1.set_ylabel('Y')
ax1.set_zlabel('Z')

# Scaled Cylinder
ax2 = fig.add_subplot(122, projection='3d')
# Plot the surface of the sphere
ax2.plot_surface(rotated_x, rotated_y, rotated_z, facecolors=colors, edgecolor='RED', linewidth=0.5)

# Set labels for clarity
ax2.set_xlabel('X')
ax2.set_ylabel('Y')
ax2.set_zlabel('Z')

plt.show()
# Out:
# C:\Users\nigel\AppData\Local\Temp\ipykernel_24976\1438115565.py:6: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap = cm.get_cmap('viridis')
